# %%
import tweepy
import csv

custemer_key = 'vjhVJGbHtN2Icc17KlxZ7L8ku'
custemer_secret ='HhCLtDduh6KJgs07gdhjF4pddsngDRiqkJvJVdT2fQ9dftrK8N'
akses_token = '1185112684515119104-V1AsTrmDsxPFkj1V4HRntwTUpTf2NG'
akses_token_secret = 'HQVC1ucIolLLdR2N3moSD6yNu2YNwygEZsSaIFtOBv0hI'
auth = tweepy.OAuthHandler(custemer_key,custemer_secret)
auth.set_access_token(akses_token,akses_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
csvFile = open('corona.csv','a')
csvWriter = csv.writer(csvFile)
for tweet in tweepy.Cursor(api.search,q="#covid19",count= 50,lang="id", 
                          since="2020-03-19").items():
    print(tweet.created_at, tweet.text, tweet.favorite_count)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'),tweet.favorite_count ])
# Out:
# 2020-06-07 17:01:55 RT @CommuterLine: #RekanCommuters mulai 8 Juni 2020 akan berlaku sejumlah aturan tambahan dalam menggunakan KRL. Untuk barang bawaan hanya… 0
# 2020-06-07 17:01:22 RT @bayubahak: becandaan nya mama ku kok gini ya? masuk kriteria talent di @MajelisLucu belum ini, siapa tau bisa gw eksploitasi. haha
# #new… 0
# 2020-06-07 16:59:41 Abis maghrib ketiduran sampe jam set 12  kebangun , cek hp.
# Gak ada juga yg chat . Ok #newnormal 0
# 2020-06-07 16:58:32 Bisa bisanya Satu keluarga bangun , tiba tiba makan malem semua jam segini. Emang #newnormal 0
# 2020-06-07 16:52:02 RT @bayubahak: becandaan nya mama ku kok gini ya? masuk kriteria talent di @MajelisLucu belum ini, siapa tau bisa gw eksploitasi. haha
# #new… 0
# 2020-06-07 16:51:46 RT @bayubahak: becandaan nya mama ku kok gini ya? masuk kriteria talent di @MajelisLucu belum ini, siapa tau bisa gw eksploitasi. haha
# #new… 0
# 2020-06-07 16:50:35 RT @idris_raman: Lindungi Kamu dan Aku
# Mari Kita Saling Melindungi
#
# ...

# %%
import pandas as pd
import numpy as np
data = 'newnormal.csv'
dataset = pd.read_csv(data)
dataset.head()
# Out:
#                  waktu                                              tweet  \
# 0  2020-06-07 17:01:22  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 1  2020-06-07 16:59:41  b'Abis maghrib ketiduran sampe jam set 12  keb...
# 2  2020-06-07 16:58:32  b'Bisa bisanya Satu keluarga bangun , tiba tib...
# 3  2020-06-07 16:52:02  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 4  2020-06-07 16:51:46  b'RT @bayubahak: becandaan nya mama ku kok gin...
#
#    like
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
dataset['waktu']
# Out:
# 0      2020-06-07 17:01:22
# 1      2020-06-07 16:59:41
# 2      2020-06-07 16:58:32
# 3      2020-06-07 16:52:02
# 4      2020-06-07 16:51:46
#               ...
# 324    2020-06-07 14:06:01
# 325    2020-06-07 14:05:40
# 326    2020-06-07 14:05:38
# 327    2020-06-07 14:04:29
# 328    2020-06-07 14:03:20
# Name: waktu, Length: 329, dtype: object

# %%
dataset['tweet']
# Out:
# 0      b'RT @bayubahak: becandaan nya mama ku kok gin...
# 1      b'Abis maghrib ketiduran sampe jam set 12  keb...
# 2      b'Bisa bisanya Satu keluarga bangun , tiba tib...
# 3      b'RT @bayubahak: becandaan nya mama ku kok gin...
# 4      b'RT @bayubahak: becandaan nya mama ku kok gin...
#                              ...
# 324    b'RT @bayubahak: becandaan nya mama ku kok gin...
# 325    b'Esok pagi, sebagian dari kita sudah mulai be...
# 326    b'RT @IndonesiaBaikId: Saat ini pemerintah mel...
# 327    b'RT @bayubahak: becandaan nya mama ku kok gin...
# 328    b'RT @rmolbantencom: Presidential Treshold Kem...
# Name: tweet, Length: 329, dtype: object

# %%
dataset['like']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 324    0
# 325    9
# 326    0
# 327    0
# 328    0
# Name: like, Length: 329, dtype: int64

# %%
df=columns
Index(['waktu', ' tweet', ' like'],dtype='object')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ae333b30f5ba> in <module>
# ----> 1 df=columns
#       2 Index(['waktu', ' tweet', ' like'],dtype='object')
#
# NameError: name 'columns' is not defined

# %%
train_features = train[['waktu', ' tweet', ' like']] # works OK
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-77b8a17c9dc0> in <module>
# ----> 1 train_features = train[['waktu', ' tweet', ' like']] # works OK
#
# NameError: name 'train' is not defined

# %%
dataset.head()
# Out:
#                  waktu                                              tweet  \
# 0  2020-06-07 17:01:22  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 1  2020-06-07 16:59:41  b'Abis maghrib ketiduran sampe jam set 12  keb...
# 2  2020-06-07 16:58:32  b'Bisa bisanya Satu keluarga bangun , tiba tib...
# 3  2020-06-07 16:52:02  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 4  2020-06-07 16:51:46  b'RT @bayubahak: becandaan nya mama ku kok gin...
#
#    like
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
dataset.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-78a5b8627168> in <module>
# ----> 1 dataset.isnull()
#
# NameError: name 'dataset' is not defined

# %%
dataset.isnull().sum()
# Out:
# waktu    0
# tweet    0
# like     0
# dtype: int64

# %%
dataset.fillna('#')
# Out:
#                    waktu                                              tweet  \
# 0    2020-06-07 17:01:22  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 1    2020-06-07 16:59:41  b'Abis maghrib ketiduran sampe jam set 12  keb...
# 2    2020-06-07 16:58:32  b'Bisa bisanya Satu keluarga bangun , tiba tib...
# 3    2020-06-07 16:52:02  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 4    2020-06-07 16:51:46  b'RT @bayubahak: becandaan nya mama ku kok gin...
# ..                   ...                                                ...
# 324  2020-06-07 14:06:01  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 325  2020-06-07 14:05:40  b'Esok pagi, sebagian dari kita sudah mulai be...
# 326  2020-06-07 14:05:38  b'RT @IndonesiaBaikId: Saat ini pemerintah mel...
# 327  2020-06-07 14:04:29  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 328  2020-06-07 14:03:20  b'RT @rmolbantencom: Presidential Treshold Kem...
#
#      like
# 0       0
# 1       0
# 2       0
# ...

# %%
dataset.isnull()
# Out:
#      waktu  tweet   like
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 4    False  False  False
# ..     ...    ...    ...
# 324  False  False  False
# 325  False  False  False
# 326  False  False  False
# 327  False  False  False
# 328  False  False  False
#
# [329 rows x 3 columns]

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#                    waktu                                              tweet  \
# 0    2020-06-07 17:01:22  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 1    2020-06-07 16:59:41  b'Abis maghrib ketiduran sampe jam set 12  keb...
# 2    2020-06-07 16:58:32  b'Bisa bisanya Satu keluarga bangun , tiba tib...
# 3    2020-06-07 16:52:02  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 4    2020-06-07 16:51:46  b'RT @bayubahak: becandaan nya mama ku kok gin...
# ..                   ...                                                ...
# 324  2020-06-07 14:06:01  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 325  2020-06-07 14:05:40  b'Esok pagi, sebagian dari kita sudah mulai be...
# 326  2020-06-07 14:05:38  b'RT @IndonesiaBaikId: Saat ini pemerintah mel...
# 327  2020-06-07 14:04:29  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 328  2020-06-07 14:03:20  b'RT @rmolbantencom: Presidential Treshold Kem...
#
#      like
# 0       0
# 1       0
# 2       0
# ...

# %%
dataset.head()
# Out:
#                  waktu                                              tweet  \
# 0  2020-06-07 17:01:22  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 1  2020-06-07 16:59:41  b'Abis maghrib ketiduran sampe jam set 12  keb...
# 2  2020-06-07 16:58:32  b'Bisa bisanya Satu keluarga bangun , tiba tib...
# 3  2020-06-07 16:52:02  b'RT @bayubahak: becandaan nya mama ku kok gin...
# 4  2020-06-07 16:51:46  b'RT @bayubahak: becandaan nya mama ku kok gin...
#
#    like
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import string 
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory



k = df

print()

case_folding =df.lower()
print("Case Folding:")
print(case_folding)
print()
fil= case_folding.translate(str.maketrans("","",string.punctuation))
print("Filtering")
print(fil)
print()
print('Stemming')
factory = StemmerFactory()
stemmer = factory.create_stemmer()
stemm = stemmer.stem(fil)
print(stemm)
print()
tokens = word_tokenize(stemm)
print("Tokenize")
print(tokens)

stopword = set(stopwords.words('Indonesian'))
removed =[]

for t in tokens:
    if t not in stopword:
        removed.append(t)
print()
print('stopwords removal')
print(removed)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-0121b2d59212> in <module>
#      11 print()
#      12
# ---> 13 case_folding =df.lower()
#      14 print("Case Folding:")
#      15 print(case_folding)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'lower'

# %%
like = df['Like']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Like'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-90620ea992ea> in <module>
# ----> 1 like = df['Like']
#
# ...

# %%
from pandas.plotting import scatter_matrix
plotting = scatter_matrix
plotting(df[['like', 'waktu', 'tweet']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-11a79ac304fd> in <module>
#       1 from pandas.plotting import scatter_matrix
#       2 plotting = scatter_matrix
# ----> 3 plotting(df[['like', 'waktu', 'tweet']])
#
# NameError: name 'df' is not defined
